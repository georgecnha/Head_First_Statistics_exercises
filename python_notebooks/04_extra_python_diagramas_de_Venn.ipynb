# %% [markdown]
# # Construindo diagramas de Venn no Python
#
# Fonte: https://www.askpython.com/python/examples/venn-diagrams-in-python

# %%
# !pip install matplotlib_venn
# Out:
# Requirement already satisfied: matplotlib_venn in c:\users\george pontes\anaconda3\lib\site-packages (0.11.7)
# Requirement already satisfied: scipy in c:\users\george pontes\anaconda3\lib\site-packages (from matplotlib_venn) (1.7.3)
# Requirement already satisfied: numpy in c:\users\george pontes\anaconda3\lib\site-packages (from matplotlib_venn) (1.21.5)
# Requirement already satisfied: matplotlib in c:\users\george pontes\anaconda3\lib\site-packages (from matplotlib_venn) (3.5.1)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\george pontes\anaconda3\lib\site-packages (from matplotlib->matplotlib_venn) (3.0.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\george pontes\anaconda3\lib\site-packages (from matplotlib->matplotlib_venn) (2.8.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\george pontes\anaconda3\lib\site-packages (from matplotlib->matplotlib_venn) (9.0.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\george pontes\anaconda3\lib\site-packages (from matplotlib->matplotlib_venn) (1.3.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\george pontes\anaconda3\lib\site-packages (from matplotlib->matplotlib_venn) (4.25.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\george pontes\anaconda3\lib\site-packages (from matplotlib->matplotlib_venn) (21.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\george pontes\anaconda3\lib\site-packages (from matplotlib->matplotlib_venn) (0.11.0)
# Requirement already satisfied: six>=1.5 in c:\users\george pontes\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->matplotlib_venn) (1.16.0)

# %%
import pandas as pd
from matplotlib import pyplot as plt
from matplotlib_venn import venn2
from matplotlib_venn import venn3

# %%
data = {'Cheetahs': ['Cat family','Speed','Yellow Fur','Day Animal',
                     'Black spots','Black line','Same Prey','Can not climb','Mammals','No Roar'],
        'Leopards': ['Cat family','Strength','Yellow Fur','Night Animal',
                     'Black spots','No Black line','Same Prey','Can climb','Mammals','Roar']
       }
df = pd.DataFrame(data, columns = ['Cheetahs', 'Leopards'])
print(df)

plt.style.use('seaborn')
 
plt.figure(figsize=(10,10))
plt.title("Venn Diagram For Cheetahs v/s Leopards")
 
venn2([set(df['Cheetahs'].to_list()), 
       set(df['Leopards'].to_list())],
       set_labels=('Cheetahs', 'Leopards')
     )
 
plt.show()
# Out:
#         Cheetahs       Leopards
# 0     Cat family     Cat family
# 1          Speed       Strength
# 2     Yellow Fur     Yellow Fur
# 3     Day Animal   Night Animal
# 4    Black spots    Black spots
# 5     Black line  No Black line
# 6      Same Prey      Same Prey
# 7  Can not climb      Can climb
# 8        Mammals        Mammals
# 9        No Roar           Roar

# %%
plt.style.use('seaborn')
 
plt.figure(figsize=(10,10))
plt.title("Venn Diagram For Random Sets")
 
# (Set1,Set2,Union)
venn2(subsets = (20, 10, 2), 
      set_labels = ('SET A', 'SET B', 'SET C'))
 
plt.show()

# %%
plt.style.use('seaborn')
 
plt.figure(figsize=(10,10))
plt.title("Venn Diagram For Three Random Sets")
 
# (Set1,Set2,1n2,Set3,1n3,2n3,1n2n3)
venn3(subsets=(10, 5, 2, 8, 6, 2, 7), 
      set_labels=('Group A', 'Group B', 'Group C'))
 
plt.show()
